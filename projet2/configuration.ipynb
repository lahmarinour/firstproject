# %%
import os

# Chemins de stockages
BASE_DIR = os.path.dirname(os.path.abspath(__file__))
DATA_DIR = os.path.join(BASE_DIR, "data")
os.makedirs(DATA_DIR, exist_ok=True)

# Fichiers intermédiaires
FILE_SOCIAL_RAW = os.path.join(DATA_DIR, "social_raw.csv")
FILE_STOCKS_RAW = os.path.join(DATA_DIR, "stocks_raw.csv")
FILE_PROCESSED = os.path.join(DATA_DIR, "sentiment_processed.csv")
FILE_MERGED = os.path.join(DATA_DIR, "merged_dataset.csv")

# Paramètres par défaut
DEFAULT_LOOKBACK_DAYS = 30
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2
#       3 # Chemins de stockages
# ----> 4 BASE_DIR = os.path.dirname(os.path.abspath(__file__))
#       5 DATA_DIR = os.path.join(BASE_DIR, "data")
#       6 os.makedirs(DATA_DIR, exist_ok=True)
#       7
#
# NameError: name '__file__' is not defined
